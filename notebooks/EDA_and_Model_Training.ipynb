# %% [markdown]
# # Disease Prediction: EDA and Training
# This notebook explores the included synthetic dataset and runs the reproducible training pipeline.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..').resolve()
df = pd.read_csv(ROOT / 'data' / 'disease_prediction_dataset_expanded.csv')
df.shape

# %%
df['Split'].value_counts(), df['Disease'].nunique(), df['Disease'].value_counts().head(20)

# %%
symptoms = pd.read_csv(ROOT / 'data' / 'symptom_dictionary.csv')['Symptom'].tolist()
df[symptoms].describe().T.head()

# %% [markdown]
# ## Train and evaluate
# Run the following cell to rebuild all model artifacts and evaluation plots.

# %%
# %run ../training/train_model.py

# %%
import json
json.loads((ROOT / 'artifacts' / 'model_metadata.json').read_text())['test_metrics']
